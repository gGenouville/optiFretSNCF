# %%
# Modules de base
import numpy as np
import os
import sys

# Module relatif à Gurobi
from gurobipy import *

module_path = os.path.abspath(os.path.join('..', 'module'))
sys.path.append(module_path)

# %%
model = Model("SNCF JALON 1")

N = None           # Nombre de wagons
M = 7           # Nombre de tâches à effectuer sur chaque wagon
S = 60*24*7     # Nombre de minutes dans une semaine    

t = {(m,n) : model.addVar(vtype = GRB.INTEGER, name = "t") for m in range(1,M+1) for n in range(1,N+1)} # Temps de début de la tâche m sur le wagon n, en minute, comptée à partir du lundi 8 Aout 2022 00:00

# %%
T = {1:15, 2:45, 3:15, 4:15, 5:150, 6:15, 7:20}       # Durée des tâches
t_a = None                                  # temps d'arrivée des wagons
t_d = None                                  # temps de départ des wagons

# %% [markdown]
# **Contraintes de temporalité des tâches sur un même wagon et respect des heures de départ et d'arrivée**

# %%
for n in range(1,N+1):
    model.addConstr(t[(1,n)] >= t_a[n])               # Début de la première tâche intervient après l'arrivée du wagon
    model.addConstr(t[(M,n)] + T[M] <= t_d[n])    # Fin de la dernière tâche avant le départ du wagon
    for m in range(1,M):
        model.addConstr(t[(m,n)] + T[m] <= t[(m+1,n)])  # Début tâche m+1 après la fin de la tâche m

# %% [markdown]
# **Contrainte permettant d'avoir au plus un wagon par machine à chaque instant**

# %%
for m in [3,5,6]:
    for n1 in range(1,N):
        for n2 in range(n1+1,N+1):
            model.addConstr((t[(m,n2)] <= t[(m,n1)] - T[m]) | (t[(m,n2)] >= t[(m,n1)] + T[m]), name=f"non_recouvrement_machine_{m}_{n1}_{n2}")   # Il faut qu'au moins une des 2 inégalités soit vérifiée

# %%
Limites = np.array([5,13,5*24+13,5*24+21,6*24+13,6*24+21,7*24+5,7*24+13])*60       # Horaires limites de la disponibilité du chantier de formation et des machines (en minutes)

for m in [3,4,5,6]:
    for n in range(1,N+1):        
        model.addConstr((t[(m,n)] <= Limites[0] - T[m]) |
                        ((t[(m,n)] >= Limites[1]) & (t[(m,n)] <= Limites[2] - T[m])) |
                        ((t[(m,n)] >= Limites[3]) & (t[(m,n)] <= Limites[4]- T[m])) |
                        (( t[(m,n)] >= Limites[5]) & (t[(m,n)] <= Limites[6] - T[m])) |
                        (t[(m,n)] >= Limites[7]))

# %%
# -- Choix d'un paramétrage d'affichage minimaliste --
model.params.outputflag = 0 # mode muet
# -- Mise à jour du modèle  --
model.update()
# -- Résolution --
model.optimize()

if model.status == GRB.INFEASIBLE:
    print("Le modèle n'a pas de solution")
elif m.status == GRB.UNBOUNDED:
    print("Le modèle est non borné")
else:
    print("L'objectif à l'optimal a pour valeur : ", m.ObjVal)
