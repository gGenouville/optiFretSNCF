# %%
import os
import sys

module_path = os.path.abspath("..")
sys.path.append(module_path)
from module.modele2 import init_model
from module.parser import (
    lightning_mcqueen_parser,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 module_path = os.path.abspath("..")
#       5 sys.path.append(module_path)
# ----> 6 from module.modele2 import init_model
#       7 from module.parser import (
#       8     lightning_mcqueen_parser,
#       9 )
#
# File c:\Users\ggeno\OneDrive\Documents\optiFretSNCF\code\module\modele2.py:25
#       1 """
#       2 Module de gestion des opérations sur les trains utilisant Gurobi pour l'optimisation.
#       3
#    (...)
#      20 init_objectif : Crée la variable à minimiser de la fonction object ainsi que ses contraintes.
#      21 """
#      23 import gurobipy as grb
# ---> 25 from module.contraintes2 import init_contraintes
#      26 from module.constants import Chantiers, Taches
#      29 def init_model(
#      30     liste_id_train_arrivee: list,
#      31     t_a: dict,
#    (...)
#      48     nb_cycle_jour
#      49 ) -> tuple[grb.Model, dict, dict, dict]:
#
# File c:\Users\ggeno\OneDrive\Documents\optiFretSNCF\code\module\contraintes2.py:27
#      24 import gurobipy as grb
#      25 from tqdm import tqdm
# ---> 27 from module.utils2 import (
#      28     Chantiers,
#      29     Machines,
#      30     Taches,
#      31     creation_limites_chantiers,
#      32     creation_limites_machines,
#      33 )
#      36 def init_contraintes(
#      37     model: grb.Model,
#      38     t_arr: dict,
#    (...)
#      62     nb_cycle_jour,
#      63 ) -> bool:
#      64     """
#      65     Initialise les contraintes du modèle d'optimisation.
#      66
#    (...)
#     104         Toujours True après l'initialisation des contraintes.
#     105     """
#
# ModuleNotFoundError: No module named 'module.utils2'

# %%
(
    first_arr,
    dernier_depart,
    monday,
    nb_roulements,
    #
    df_sillons_arr,
    df_sillons_dep,
    df_correspondance,
    df_chantiers,
    df_machines,
    df_roulement_agent,
    #
    dict_t_a,
    dict_t_d,
    dict_correspondances,
    dict_limites_chantiers,
    dict_limites_machines,
    dict_limites_voies,
    dict_max_agents,
    dict_roulements_operants_sur_tache,
    dict_h_deb,
    dict_nb_cycles_agents,
    dict_nb_cycle_jour,
    dict_comp_arr,
    dict_comp_dep,
    ) = lightning_mcqueen_parser("./instance_WPY_simple.xlsx")

# %%
t_a= dict_t_a
t_d = dict_t_d
D = dict_correspondances
file="./instance_WPY_simple.xlsx"
id_file = 2
limites_voies=dict_limites_voies
temps_max=dernier_depart
temps_min=first_arr
nb_cycles_agents=dict_nb_cycles_agents
h_deb = dict_h_deb
nb_roulements=nb_roulements
equip=dict_roulements_operants_sur_tache
max_agents_sur_roulement=dict_max_agents
#nombre_cycles=nombre_cycles_agents(file,temps_min,temps_max),
h_deb=dict_h_deb
comp_arr=dict_comp_arr,
comp_dep=dict_comp_dep,
nb_cycle_jour=dict_nb_cycle_jour

model,t_arr,t_dep, is_present = init_model(
    liste_id_train_arrivee = t_a.keys(),
    t_a = t_a,
    liste_id_train_depart = t_d.keys(),
    t_d = t_d,
    dict_correspondances = D,
    file=file,
    id_file = id_file,
    limites_voies=limites_voies,
    temps_max=temps_max,
    temps_min=temps_min,
    nb_cycles_agents=nb_cycles_agents,
    heure_debut_roulement=h_deb,
    nombre_roulements=nb_roulements,
    equip=equip,
    max_agents_sur_roulement=max_agents_sur_roulement,
    #nombre_cycles=nombre_cycles_agents(file,temps_min,temps_max),
    h_deb=h_deb,
    comp_arr=comp_arr,
    comp_dep=comp_dep,
    nb_cycle_jour=nb_cycle_jour
)
